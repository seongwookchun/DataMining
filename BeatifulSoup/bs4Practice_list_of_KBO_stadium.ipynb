# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import requests

url = 'https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EC%95%BC%EA%B5%AC%EC%9E%A5_%EB%AA%A9%EB%A1%9D'
page = requests.get(url)
# page
display(page)
print(page.status_code)
len(page.content)
# Out:
# <Response [200]>
# 200
# 161068

# %%
soup = bs(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    대한민국의 야구장 목록 - 위키백과, 우리 모두의 백과사전
#   </title>
#   <script>
#    document.documentElement.className=document.documentElement.className.replace(/(^|\s)client-nojs(\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"대한민국의_야구장_목록","wgTitle":"대한민국의 야구장 목록","wgCurRevisionId":24181677,"wgRevisionId":24181677,"wgArticleId":492219,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["깨진 링크를 가지고 있는 문서","한국어 위키백과의 링크가 위키데이터와 같은 위키공용분류","대한민국의 야구장","대한민국의 스포츠 관련 목록","야구장 목록"],"wgBreakFrames":!1,"wgPageContentLanguage":"ko","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"ko","wgMonthNames":["","1월","2월","3월","4월","5월","6월","7월","8월","9월","10월","11월","12월"],
# ...

# %%
print(type(soup.children))
list(soup.children)
# Out:
# <class 'list_iterator'>
# ['html', '\n', <html class="client-nojs" dir="ltr" lang="ko">
#  <head>
#  <meta charset="utf-8"/>
#  <title>대한민국의 야구장 목록 - 위키백과, 우리 모두의 백과사전</title>
#  <script>document.documentElement.className=document.documentElement.className.replace(/(^|\s)client-nojs(\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"대한민국의_야구장_목록","wgTitle":"대한민국의 야구장 목록","wgCurRevisionId":24181677,"wgRevisionId":24181677,"wgArticleId":492219,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["깨진 링크를 가지고 있는 문서","한국어 위키백과의 링크가 위키데이터와 같은 위키공용분류","대한민국의 야구장","대한민국의 스포츠 관련 목록","야구장 목록"],"wgBreakFrames":!1,"wgPageContentLanguage":"ko","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"ko","wgMonthNames":["","1월","2월","3월","4월","5월","6월","7월","8월","9월","10월","11월","12월"],
# ...

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
html = list(soup.children)[2]
print(type(html))
print(html.prettify())
# Out:
# <class 'bs4.element.Tag'>
# <html class="client-nojs" dir="ltr" lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    대한민국의 야구장 목록 - 위키백과, 우리 모두의 백과사전
#   </title>
#   <script>
#    document.documentElement.className=document.documentElement.className.replace(/(^|\s)client-nojs(\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"대한민국의_야구장_목록","wgTitle":"대한민국의 야구장 목록","wgCurRevisionId":24181677,"wgRevisionId":24181677,"wgArticleId":492219,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["깨진 링크를 가지고 있는 문서","한국어 위키백과의 링크가 위키데이터와 같은 위키공용분류","대한민국의 야구장","대한민국의 스포츠 관련 목록","야구장 목록"],"wgBreakFrames":!1,"wgPageContentLanguage":"ko","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"ko","wgMonthNames":["","1월","2월","3월","4월","5월","6월","7월","8월","9월","10월","11월","12월"],
# ...

# %%
print([type(item) for item in list(soup.children)])

print(list(html.children))

print(len(list(html.children)))
# Out:
# [<class 'bs4.element.Doctype'>, <class 'bs4.element.NavigableString'>, <class 'bs4.element.Tag'>, <class 'bs4.element.NavigableString'>]
# ['\n', <head>
# <meta charset="utf-8"/>
# <title>대한민국의 야구장 목록 - 위키백과, 우리 모두의 백과사전</title>
# ...

# %%
def describe(x):
    try:
        print(len(x))
    except:
        pass
    print(type(x))
    print(x)

# %%
body = list(html.children)[0]
describe(body)
print('**********************************')
body = list(html.children)[1]
describe(body)
print('**********************************')
body = list(html.children)[2]
describe(body)
# Out:
# 1
# <class 'bs4.element.NavigableString'>
#
#
# **********************************
# 49
# <class 'bs4.element.Tag'>
# <head>
# <meta charset="utf-8"/>
# <title>대한민국의 야구장 목록 - 위키백과, 우리 모두의 백과사전</title>
# ...

# %%
body = list(html.children)[3]
describe(body)
# Out:
# 17
# <class 'bs4.element.Tag'>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-대한민국의_야구장_목록 rootpage-대한민국의_야구장_목록 skin-vector action-view">
# <div class="noprint" id="mw-page-base"></div>
# <div class="noprint" id="mw-head-base"></div>
# <div class="mw-body" id="content" role="main">
# <a id="top"></a>
# <div class="mw-body-content" id="siteNotice"><!-- CentralNotice --></div>
# <div class="mw-indicators mw-body-content">
# </div>
# <h1 class="firstHeading" id="firstHeading" lang="ko">대한민국의 야구장 목록</h1>
# <div class="mw-body-content" id="bodyContent">
# <div class="noprint" id="siteSub">위키백과, 우리 모두의 백과사전.</div>
# <div id="contentSub"></div>
# <div id="jump-to-nav"></div>
# <a class="mw-jump-link" href="#mw-head">둘러보기로 가기</a>
# <a class="mw-jump-link" href="#p-search">검색하러 가기</a>
# ...

# %%
for i in range(4):
    print(len(list(html.children)[i]))
    print('**********************************')
# Out:
# 1
# **********************************
# 49
# **********************************
# 1
# **********************************
# 17
# **********************************

# %%
body = list(html.children)[3]
describe(body)
# Out:
# 17
# <class 'bs4.element.Tag'>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-대한민국의_야구장_목록 rootpage-대한민국의_야구장_목록 skin-vector action-view">
# <div class="noprint" id="mw-page-base"></div>
# <div class="noprint" id="mw-head-base"></div>
# <div class="mw-body" id="content" role="main">
# <a id="top"></a>
# <div class="mw-body-content" id="siteNotice"><!-- CentralNotice --></div>
# <div class="mw-indicators mw-body-content">
# </div>
# <h1 class="firstHeading" id="firstHeading" lang="ko">대한민국의 야구장 목록</h1>
# <div class="mw-body-content" id="bodyContent">
# <div class="noprint" id="siteSub">위키백과, 우리 모두의 백과사전.</div>
# <div id="contentSub"></div>
# <div id="jump-to-nav"></div>
# <a class="mw-jump-link" href="#mw-head">둘러보기로 가기</a>
# <a class="mw-jump-link" href="#p-search">검색하러 가기</a>
# ...

# %%
table01 = soup.find_all('table')[0]
display(table01)
# Out:
# <table class="wikitable sortable" style="font-size: 90%; text-align:left" width="98%">
# <tbody><tr style="color:white;background-color:#408080;">
# <th class="unsortable" style="color:white;background-color:#408080;" width="20px;"><b>#</b>
# </th>
# <th style="color:white;background-color:#408080;" width="15%"><b>명칭</b>
# </th>
# <th class="unsortable" style="color:white;background-color:#408080;"><b>사진</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>좌석수</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>수용인원</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>주차면적</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>소재지</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>홈 구단</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>개장 연도</b>
# </th>
# <th class="unsortable" style="color:white;background-color:#408080;"><b>주석 및 기타</b>
# </th></tr>
# <tr>
# <th>1
# </th>
# ...

# %%
table02 = soup.find('table', attrs={'class':'wikitable sortable'})
display(table02)
# Out:
# <table class="wikitable sortable" style="font-size: 90%; text-align:left" width="98%">
# <tbody><tr style="color:white;background-color:#408080;">
# <th class="unsortable" style="color:white;background-color:#408080;" width="20px;"><b>#</b>
# </th>
# <th style="color:white;background-color:#408080;" width="15%"><b>명칭</b>
# </th>
# <th class="unsortable" style="color:white;background-color:#408080;"><b>사진</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>좌석수</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>수용인원</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>주차면적</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>소재지</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>홈 구단</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>개장 연도</b>
# </th>
# <th class="unsortable" style="color:white;background-color:#408080;"><b>주석 및 기타</b>
# </th></tr>
# <tr>
# <th>1
# </th>
# ...

# %%
table_body = table02.find('tbody')
describe(table_body)
# Out:
# 20
# <class 'bs4.element.Tag'>
# <tbody><tr style="color:white;background-color:#408080;">
# <th class="unsortable" style="color:white;background-color:#408080;" width="20px;"><b>#</b>
# </th>
# <th style="color:white;background-color:#408080;" width="15%"><b>명칭</b>
# </th>
# <th class="unsortable" style="color:white;background-color:#408080;"><b>사진</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>좌석수</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>수용인원</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>주차면적</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>소재지</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>홈 구단</b>
# </th>
# <th style="color:white;background-color:#408080;"><b>개장 연도</b>
# </th>
# <th class="unsortable" style="color:white;background-color:#408080;"><b>주석 및 기타</b>
# </th></tr>
# <tr>
# <th>1
# </th>
# ...

# %%
rows = table_body.find_all('tr')
display(rows)
# Out:
# [<tr style="color:white;background-color:#408080;">
#  <th class="unsortable" style="color:white;background-color:#408080;" width="20px;"><b>#</b>
#  </th>
#  <th style="color:white;background-color:#408080;" width="15%"><b>명칭</b>
#  </th>
#  <th class="unsortable" style="color:white;background-color:#408080;"><b>사진</b>
#  </th>
#  <th style="color:white;background-color:#408080;"><b>좌석수</b>
#  </th>
#  <th style="color:white;background-color:#408080;"><b>수용인원</b>
#  </th>
#  <th style="color:white;background-color:#408080;"><b>주차면적</b>
#  </th>
#  <th style="color:white;background-color:#408080;"><b>소재지</b>
#  </th>
#  <th style="color:white;background-color:#408080;"><b>홈 구단</b>
#  </th>
#  <th style="color:white;background-color:#408080;"><b>개장 연도</b>
#  </th>
#  <th class="unsortable" style="color:white;background-color:#408080;"><b>주석 및 기타</b>
#  </th></tr>, <tr>
#  <th>1
#  </th>
# ...

# %%
data = []
print(len(rows))
i = 0
for row in rows:
    if i == 1:
        break
    print('lenth of row:', len(row))
    try:
#         print('th')
#         cols = row.find_all('th')
        try:
            cols = [ele.find('b').text.strip() for ele in cols]
        except:
            cols = [ele.text.strip() for ele in cols]
        print(cols)
    except:
        pass
    data.append([ele for ele in cols if ele])
    try:
        print('td')
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        data.append([ele for ele in cols if ele])
#         cols = [ele.text for ele in cols]     # strip() 을 추가하면 \n 개행문자를 없애준다.
    except:
        print('no tr.')
    
#     i += 1

# print(row.find('td'))
# print(data)
[len(ele) for ele in data]
# Out:
# 10
# lenth of row: 20
# td
# lenth of row: 20
# []
# td
# lenth of row: 20
# td
# lenth of row: 20
# td
# lenth of row: 20
# td
# lenth of row: 20
# td
# lenth of row: 20
# td
# lenth of row: 20
# td
# lenth of row: 20
# td
# lenth of row: 20
# td
# [5, 0, 0, 8, 8, 8, 8, 7, 7, 8, 8, 6, 6, 8, 8, 8, 8, 6, 6, 5]

# %%
print(data)
# Out:
# [['창원 NC 파크', '11,000', '창원', 'NC 다이노스', '2019'], [], [], ['대구 삼성 라이온즈 파크', '24,331', '29,178', '1,116', '대구', '삼성 라이온즈', '2016', '2016년 초 준공. 국내 최초 팔각형 구장. 천연 잔디 구장. 외야 파울 존 부근 분리형 불펜. 홈 팀 3루 덕아웃 사용.'], ['대구 삼성 라이온즈 파크', '24,331', '29,178', '1,116', '대구', '삼성 라이온즈', '2016', '2016년 초 준공. 국내 최초 팔각형 구장. 천연 잔디 구장. 외야 파울 존 부근 분리형 불펜. 홈 팀 3루 덕아웃 사용.'], ['광주-기아 챔피언스 필드', '20,500', '27,000', '1,106', '광주', 'KIA 타이거즈', '2014', '천연 잔디 구장. 국내 최초의 개방형 구장. 외야 펜스 부근 분리형 불펜. 홈 팀 3루 덕아웃 사용.'], ['광주-기아 챔피언스 필드', '20,500', '27,000', '1,106', '광주', 'KIA 타이거즈', '2014', '천연 잔디 구장. 국내 최초의 개방형 구장. 외야 펜스 부근 분리형 불펜. 홈 팀 3루 덕아웃 사용.'], ['인천 SK 행복드림구장', '26,000', '4,002', '인천', 'SK 와이번스', '2002', '천연 잔디 구장. 외야 펜스 부근 분리형 불펜. [1][2][3][4][5] 홈 팀 1루 덕아웃 사용.'], ['인천 SK 행복드림구장', '26,000', '4,002', '인천', 'SK 와이번스', '2002', '천연 잔디 구장. 외야 펜스 부근 분리형 불펜. [1][2][3][4][5] 홈 팀 1루 덕아웃 사용.'], ['수원 kt 위즈 파크', '22,067', '25,000', '1,318', '수원', 'kt 위즈', '1989', '2014년 리모델링. 천연 잔디 구장. 외야 파울 존 부근 분리형 불펜.[6] 홈 팀 1루 덕아웃 사용.'], ['수
# ...

# %%
DFdata = pd.DataFrame(data)
display(DFdata)
# Out:
#                 0       1           2        3        4  \
# 0        창원 NC 파크  11,000          창원  NC 다이노스     2019
# 1            None    None        None     None     None
# 2            None    None        None     None     None
# 3   대구 삼성 라이온즈 파크  24,331      29,178    1,116       대구
# 4   대구 삼성 라이온즈 파크  24,331      29,178    1,116       대구
# 5   광주-기아 챔피언스 필드  20,500      27,000    1,106       광주
# 6   광주-기아 챔피언스 필드  20,500      27,000    1,106       광주
# 7    인천 SK 행복드림구장  26,000       4,002       인천  SK 와이번스
# 8    인천 SK 행복드림구장  26,000       4,002       인천  SK 와이번스
# 9     수원 kt 위즈 파크  22,067      25,000    1,318       수원
# 10    수원 kt 위즈 파크  22,067      25,000    1,318       수원
# 11         사직 야구장  26,800          부산  롯데 자이언츠     1985
# 12         사직 야구장  26,800          부산  롯데 자이언츠     1985
# 13         잠실 야구장  25,553      26,000    1,279       서울
# 14         잠실 야구장  25,553      26,000    1,279       서울
# 15         고척스카이돔  17,000  22,258[10]      492       서울
# ...

# %% [markdown]
# # Throwing out "none"

# %%
data = []
print(len(rows))
i = 0
for row in rows:
    temp = []
    if i == 1:
        break
        
    try:
        print('th')
        cols = row.find_all('th')
        try:
            cols = [ele.find('b').text.strip() for ele in cols]
        except:
            cols = [ele.text.strip() for ele in cols]
        print(cols)
    except:
        pass
    temp.append([ele for ele in cols if ele])
    try:
        print('td')
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        temp.append([ele for ele in cols if ele])
#         cols = [ele.text for ele in cols]     # strip() 을 추가하면 \n 개행문자를 없애준다.
    except:
        print('no tr.')
    
    temp2 = []
    for item in temp:
        for jtem in item:
            temp2.append(jtem)
    data.append(temp2)
#     print('len(temp) : ', len(temp))
#     i += 1

# print(row.find('td'))
# print(data)
[len(ele) for ele in data]
# Out:
# 10
# th
# ['#', '명칭', '사진', '좌석수', '수용인원', '주차면적', '소재지', '홈 구단', '개장 연도', '주석 및 기타']
# td
# th
# ['1']
# td
# th
# ['2']
# td
# th
# ['3']
# td
# th
# ['4']
# td
# th
# ['5']
# td
# th
# ['6']
# td
# th
# ['7']
# td
# th
# ['8']
# td
# th
# ['9']
# td
# [10, 9, 9, 8, 9, 7, 9, 9, 7, 6]

# %%
print(data)
# Out:
# [['#', '명칭', '사진', '좌석수', '수용인원', '주차면적', '소재지', '홈 구단', '개장 연도', '주석 및 기타'], ['1', '대구 삼성 라이온즈 파크', '24,331', '29,178', '1,116', '대구', '삼성 라이온즈', '2016', '2016년 초 준공. 국내 최초 팔각형 구장. 천연 잔디 구장. 외야 파울 존 부근 분리형 불펜. 홈 팀 3루 덕아웃 사용.'], ['2', '광주-기아 챔피언스 필드', '20,500', '27,000', '1,106', '광주', 'KIA 타이거즈', '2014', '천연 잔디 구장. 국내 최초의 개방형 구장. 외야 펜스 부근 분리형 불펜. 홈 팀 3루 덕아웃 사용.'], ['3', '인천 SK 행복드림구장', '26,000', '4,002', '인천', 'SK 와이번스', '2002', '천연 잔디 구장. 외야 펜스 부근 분리형 불펜. [1][2][3][4][5] 홈 팀 1루 덕아웃 사용.'], ['4', '수원 kt 위즈 파크', '22,067', '25,000', '1,318', '수원', 'kt 위즈', '1989', '2014년 리모델링. 천연 잔디 구장. 외야 파울 존 부근 분리형 불펜.[6] 홈 팀 1루 덕아웃 사용.'], ['5', '사직 야구장', '26,800', '부산', '롯데 자이언츠', '1985', '천연 잔디 구장.외야 파울 존 부근 분리형 불펜.[3][4][7][8][9] 홈 팀 1루 덕아웃 사용.'], ['6', '잠실 야구장', '25,553', '26,000', '1,279', '서울', 'LG 트윈스 두산 베어스', '1982', '천연 잔디 구장. 내야 파울 존 부근 분리형 불펜. 홈 팀 1루 덕아웃 사용.'], ['7', '고척스카이돔', '17,000', '22,258[10]', '492', '서울', '키움 히어로즈', '2015', '인조 잔디 구장. 폐쇄형 지하불펜. 홈 팀 1루 덕아웃 사용.'], ['8', '한화생명 이글스 파크
# ...

# %%
DFdata = pd.DataFrame(data)
display(DFdata)
# Out:
#    0              1       2           3        4        5  \
# 0  #             명칭      사진         좌석수     수용인원     주차면적
# 1  1  대구 삼성 라이온즈 파크  24,331      29,178    1,116       대구
# 2  2  광주-기아 챔피언스 필드  20,500      27,000    1,106       광주
# 3  3   인천 SK 행복드림구장  26,000       4,002       인천  SK 와이번스
# 4  4    수원 kt 위즈 파크  22,067      25,000    1,318       수원
# 5  5         사직 야구장  26,800          부산  롯데 자이언츠     1985
# 6  6         잠실 야구장  25,553      26,000    1,279       서울
# 7  7         고척스카이돔  17,000  22,258[10]      492       서울
# 8  8    한화생명 이글스 파크  13,000          대전   한화 이글스     1964
# 9  9       창원 NC 파크  11,000          창원  NC 다이노스     2019
#
#                                                    6  \
# 0                                                소재지
# 1                                            삼성 라이온즈
# 2                                           KIA 타이거즈
# 3                                               2002
# 4                                              kt 위즈
# ...
